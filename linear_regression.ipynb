# %% [markdown]
# ### Regression
#
# - Regression searches for relationships among variables.
# - In regression we have to find out the function that maps some features or variables to other sufficiently well.
# - Dependent features are Dependent Variables, output and the Independent features are independent variables, inputs.
#
# ## Linear Regression:
#
# -  linear relationship between 𝑦 and 𝐱: 𝑦 = 𝛽₀ + 𝛽₁𝑥₁ + ⋯ + 𝛽ᵣ𝑥ᵣ + 𝜀.
#
# - dependent variable 𝑦, independent variables 𝐱 = (𝑥₁, …, 𝑥ᵣ), where 𝑟 is the number of predictors, 𝛽₀, 𝛽₁, …, 𝛽ᵣ are the regression coefficients, and 𝜀 is the random error.
#
# ### Simple Linear Regression
#
# - simplest case of linear regression
#
# - it has a single independent variable, 𝐱 = 𝑥
# ![fig-lin-reg.a506035b654a.png](data:image/png;base64,...)
#
# ### Simple Linear Regression with sckit-learn
# To install scikit learn
# `py -m pip install numpy scikit-learn`

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
# Provide data
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])

# %%
x
# Out:
# array([[ 5],
#        [15],
#        [25],
#        [35],
#        [45],
#        [55]])

# %%
y
# Out:
# array([ 5, 20, 14, 32, 22, 38])

# %%
# Create a model and fit it
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
print(f"coefficient of determination: {r_sq}")
# Out:
# coefficient of determination: 0.7158756137479542

# %%
print(f"intercept: {model.intercept_}")
# Out:
# intercept: 5.633333333333329

# %%
print(f"slope: {model.coef_}")
# Out:
# slope: [0.54]

# %% [markdown]
# ### Another Example

# %%
# importing models
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split

# %%
url = 'https://gist.githubusercontent.com/jiisanda/b3c617053f2338d5f29fa75715cf9141/raw/3aeed18f15466542e6627224a0508da4ed61794f/dataset.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# Data Validation
# Shape
print("Number of columns:", df.shape[1])
print("Number of rows: ", df.shape[0])
# info
df.info()
# description
df.describe()
# Out:
# Number of columns: 2
# Number of rows:  30
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.scatter(x = df['YearsExperience'], y = df['Salary'], color = 'blue', edgecolor='black', linewidth=1)

plt.title('Salary w.r.t years of experience')
plt.xlabel('Years of Expericne')
plt.ylabel('Salary')


plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 2) Data Preprocessing

# %%
# Define Predictor and target Attribute
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

# %%
# Splitting the data to training and testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# Training Data Set
print("X_test", X_train.shape)
print("X_test", y_train.shape)
# Out:
# X_test (24, 1)
# X_test (24,)

# %%
# Testing Data Set
print("X_test", X_test.shape)
print("X_test", y_test.shape)
# Out:
# X_test (6, 1)
# X_test (6,)

# %% [markdown]
# 3) Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# 4) Evaluate Result

# %%
# Visualizing the result
plt.scatter(X_test, y_test, color = 'blue', edgecolor='black', linewidth=1)
plt.plot(X_test, y_pred, color = 'red', linewidth = 1)

plt.title('Salary w.r.t years of experience')
plt.xlabel('Years of Expericne')
plt.ylabel('Salary')


plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
